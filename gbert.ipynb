# %%
# !pip install git+https://github.com/google-research/bert.git
# Out:
# ...
#   Cloning https://github.com/google-research/bert.git to /tmp/pip-req-build-px47gpbd
#   Running command git clone -q https://github.com/google-research/bert.git /tmp/pip-req-build-px47gpbd
#   Resolved https://github.com/google-research/bert.git to commit eedf5716ce1268e56f0a50264a88cafad334ac61
# ERROR: File "setup.py" not found for legacy project git+https://github.com/google-research/bert.git.

# %%
# BERT_BASE_DIR="/gbert/uncased_L-12_H-768_A-12"
# export GLUE_DIR=/path/to/glue

# %%
# !python gbert/create_pretraining_data.py \
  --input_file=./sample_text.txt \
  --output_file=models/tmp-gbert/tf_examples.tfrecord \
  --vocab_file=gbert/uncased_L-12_H-768_A-12/vocab.txt \
  --do_lower_case=True \
  --max_seq_length=128 \
  --max_predictions_per_seq=20 \
  --masked_lm_prob=0.15 \
  --random_seed=12345 \
  --dupe_factor=5
# Out:
# /home/csenitmz/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/csenitmz/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/csenitmz/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python gbert/run_pretraining.py \
  --input_file=models/tmp-gbert/tf_examples.tfrecord \
  --output_dir=models/tmp-gbert/pretraining_output \
  --do_train=True \
  --do_eval=True \
  --bert_config_file=gbert/uncased_L-12_H-768_A-12/bert_config.json \
  --init_checkpoint=gbert/uncased_L-12_H-768_A-12/bert_model.ckpt \
  --train_batch_size=32 \
  --max_seq_length=128 \
  --max_predictions_per_seq=20 \
  --num_train_steps=20 \
  --num_warmup_steps=10 \
  --learning_rate=2e-5
# Out:
# /home/csenitmz/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/csenitmz/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/csenitmz/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
